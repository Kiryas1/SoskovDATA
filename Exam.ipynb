# %%
import pandas as pd
import redis as rd

# %%
D = pd.read_csv("https://github.com/junaart/ForStudents/raw/refs/heads/main/Big_Data/Exam/data.csv")

# %%
D
# Out:
#         id             a1                 a2           a3                a4  \
# 0        1         shrimp            almonds      avocado    vegetables mix
# 1        2        burgers          meatballs         eggs               NaN
# 2        3        chutney                NaN          NaN               NaN
# 3        4         turkey            avocado          NaN               NaN
# 4        5  mineral water               milk   energy bar  whole wheat rice
# ...    ...            ...                ...          ...               ...
# 7496  7497         butter         light mayo  fresh bread               NaN
# 7497  7498        burgers  frozen vegetables         eggs      french fries
# 7498  7499        chicken                NaN          NaN               NaN
# 7499  7500       escalope          green tea          NaN               NaN
# 7500  7501           eggs    frozen smoothie  yogurt cake    low fat yogurt
#
# ...

# %%
r=rd.Redis(host='localhost', db=0)
key = "a1"
for i in range(len(D['a1'])):
    r.set(key+str(i),str(D['a1'].iloc[i]))

# %%
r=rd.Redis(host='localhost', db=0)
key = "a2"
for i in range(len(D['a2'])):
    r.set(key+str(i),str(D['a2'].iloc[i]))

# %%
r=rd.Redis(host='localhost', db=0)
key = "a3"
for i in range(len(D['a3'])):
    r.set(key+str(i),str(D['a3'].iloc[i]))

# %%
r=rd.Redis(host='localhost', db=0)
key = "id"
for i in range(len(D['id'])):
    r.set(key+str(i),str(D['id'].iloc[i]))

# %%
r=rd.Redis(host='localhost', db=0)
key = "a4"
for i in range(len(D['a4'])):
    r.set(key+str(i),str(D['a4'].iloc[i]))

# %%
r=rd.Redis(host='localhost', db=0)
key = "a5"
for i in range(len(D['a5'])):
    r.set(key+str(i),str(D['a5'].iloc[i]))

# %%
r=rd.Redis(host='localhost', db=0)
key = "a6"
for i in range(len(D['a6'])):
    r.set(key+str(i),str(D['a6'].iloc[i]))

# %%
r=rd.Redis(host='localhost', db=0)
key = "a7"
for i in range(len(D['a7'])):
    r.set(key+str(i),str(D['a7'].iloc[i]))

# %%
r=rd.Redis(host='localhost', db=0)
key = "a8"
for i in range(len(D['a8'])):
    r.set(key+str(i),str(D['a8'].iloc[i]))

# %%
r=rd.Redis(host='localhost', db=0)
key = "a9"
for i in range(len(D['a9'])):
    r.set(key+str(i),str(D['a9'].iloc[i]))

# %%
r=rd.Redis(host='localhost', db=0)
key = "a10"
for i in range(len(D['a10'])):
    r.set(key+str(i),str(D['a10'].iloc[i]))
